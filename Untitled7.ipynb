# %%
import pandas as pd

# %%
#Q1
df = pd.read_csv('services.csv')

# %%
# Head
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#Tail
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#Columns
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#describe
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
#index
df.index
# Out:
# RangeIndex(start=0, stop=23, step=1)

# %%
#Q2
a = [3,8,6,2,9]
b = [5,2,9,3,1]
c = [1,7,4,5,2]
data = list(zip(a,b,c))
df = pd.DataFrame(data,columns=['A','B','C'])

# %%
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df.index+=1

# %%
df[['A','B','C']]+2
# Out:
#     A   B  C
# 1   5   7  3
# 2  10   4  9
# 3   8  11  6
# 4   4   5  7
# 5  11   3  4

# %%
#Q3
data = [10, 20, 30, 40, 50]
df = pd.DataFrame(data,columns=['values'])

# %%
df[:3].sum(axis=0)
# Out:
# values    60
# dtype: int64

# %%
#Q$
test = ['aeroplane','spaceship','hovercraft','dog','chocolate']
words_count = []
for i in test:
    words_count.append(len(i))

# %%
data ={'test':test,'words_count':words_count}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          test  words_count
# 0   aeroplane            9
# 1   spaceship            9
# 2  hovercraft           10
# 3         dog            3
# 4   chocolate            9

# %%
#Q6
# pandas.read_excel is used to read excel files in pandas.

# %%
email = ['romariovalncia@newsgetz.com','zss87@discretevtd.com', 'lyneverovskaya@sunfuesty.com', 
         'sapomagallanero@hairstylesbase.com','darkness2287@tradegrowth.com']
username = []
for i in email:
    username.append(i.split('@')[0])

# %%
data = {'email' : email, 'username' : username}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                 email         username
# 0         romariovalncia@newsgetz.com   romariovalncia
# 1               zss87@discretevtd.com            zss87
# 2        lyneverovskaya@sunfuesty.com   lyneverovskaya
# 3  sapomagallanero@hairstylesbase.com  sapomagallanero
# 4        darkness2287@tradegrowth.com     darkness2287

# %%
#Q7
a = [3,8,6,2,9]
b = [5,2,9,3,1]
c = [1,7,4,5,2]
data = list(zip(a,b,c))
df = pd.DataFrame(data,columns=['A','B','C'])

# %%
df[(df.A>5) & (df.B<10)]
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
#Q8
data = [10, 20, 30, 40, 50]
df = pd.DataFrame(data,columns=['values'])

# %%
df.mean(), df.median(), df.std()
# Out:
# (values    30.0
#  dtype: float64,
#  values    30.0
#  dtype: float64,
#  values    15.811388
#  dtype: float64)

# %%
#Q11
import datetime
day_name= ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']
date = ['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']
day = []
for i in date:
    day.append(datetime.datetime.strptime(i, '%Y-%m-%d').weekday())
for i in range(len(day)):
    day[i] = day_name[day[i]]

# %%
data = {'Date':date,'Weekday':day}
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date    Weekday
# 0  2023-01-01     Sunday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-01-04  Wednesday
# 4  2023-01-05   Thursday

# %%
df[(df.Date>'2023-01-01') & (df.Date<'2023-01-31')]
# Out:
#          Date    Weekday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-01-04  Wednesday
# 4  2023-01-05   Thursday

# %%
#Q13
# To use basic functions of pandas, we need to first import pandas library.
